# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wellcome=pd.read_csv('C:/Users/rabia/Desktop/Thinkful/WELLCOME.csv',encoding='Latin-1')
wellcome.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
len(wellcome)
# Out:
# 2127

# %%
wellcome_preclean = wellcome.dropna(subset=
                                    ['Journal title','Article title','COST (£) charged to Wellcome (inc VAT when charged)'])
wellcome_clean.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  PSYCHOLOGICAL MEDICINE
# 1             PMC3679557       ACS       BIOMACROMOLECULES
# 2  23043264  PMC3506128        ACS              J MED CHEM
# 3    23438330 PMC3646402       ACS              J MED CHEM
# 4   23438216 PMC3601604        ACS              J ORG CHEM
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
len(wellcome_clean)
# Out:
# 2124

# %%
wellcome_clean['Journal title'] = wellcome_clean['Journal title'].str.title()

# %%
journal_counts = wellcome_clean['Journal title'].value_counts()
journal_counts.head(5)
# Out:
# Plos One                           188
# Journal Of Biological Chemistry     53
# Neuroimage                          29
# Plos Pathogens                      24
# Plos Genetics                       24
# Name: Journal title, dtype: int64

# %%
wellcome_five = wellcome_clean[wellcome_clean['Journal title'].isin
                                   (journal_counts.head(5).index.tolist())]

# %%
wellcome_five.head()
# Out:
#                     PMID/PMCID  \
# 16                    22610094
# 60                  PMC3576085
# 61        23239883 PMC3561570
# 64           PMCID: PMC3642348
# 65  PMID: 22992744  PMC3493908
#
#                                             Publisher  \
# 16                                              AMBSB
# 60  American Soc for Biochemistry and Molecular Bi...
# 61  American Society for Biochemistry and Molecula...
# 64  American Society for Biochemistry and Molecula...
# 65  American Society for Biochemistry and Molecula...
#
#                       Journal title  \
# 16  Journal Of Biological Chemistry
# 60  Journal Of Biological Chemistry
# 61  Journal Of Biological Chemistry
# 64  Journal Of Biological Chemistry
# 65  Journal Of Biological Chemistry
#
#                                         Article title  \
# 16                Annexin-1 interaction with FPR2/ALX
# 60  Understanding how noncatalytic carbohydrate bi...
# ...

# %%
len(wellcome_five)
# Out:
# 318

# %%
wellcome_five.loc[:,'cost'] = wellcome_five['COST (£) charged to Wellcome (inc VAT when charged)']\
                        .str.replace('£','').str.replace('$','')
wellcome_five.cost = wellcome_five.cost.astype(float)
wellcome_five = wellcome_five[wellcome_five.cost != 999999.00]
wellcome_five = wellcome_five[wellcome_five.cost != 192645.00]

# %%
wellcome_five.head()
# Out:
#                     PMID/PMCID  \
# 16                    22610094
# 60                  PMC3576085
# 61        23239883 PMC3561570
# 64           PMCID: PMC3642348
# 65  PMID: 22992744  PMC3493908
#
#                                             Publisher  \
# 16                                              AMBSB
# 60  American Soc for Biochemistry and Molecular Bi...
# 61  American Society for Biochemistry and Molecula...
# 64  American Society for Biochemistry and Molecula...
# 65  American Society for Biochemistry and Molecula...
#
#                       Journal title  \
# 16  Journal Of Biological Chemistry
# 60  Journal Of Biological Chemistry
# 61  Journal Of Biological Chemistry
# 64  Journal Of Biological Chemistry
# 65  Journal Of Biological Chemistry
#
#                                         Article title  \
# 16                Annexin-1 interaction with FPR2/ALX
# 60  Understanding how noncatalytic carbohydrate bi...
# ...

# %%
top_five = wellcome_five.groupby('Journal title').describe()
top_five
# Out:
#                                   cost                                    \
#                                  count         mean         std      min
# Journal title
# Journal Of Biological Chemistry   52.0  1423.588462  411.954360   265.67
# Neuroimage                        29.0  2215.168276  266.653947  1747.16
# Plos Genetics                     22.0  1643.110909  153.366825  1394.05
# Plos One                         180.0   935.866667  202.641328   122.31
# Plos Pathogens                    22.0  1572.866818  161.780891  1254.02
#
#
#                                        25%      50%        75%      max
# Journal title
# Journal Of Biological Chemistry  1152.1900  1301.14  1609.8225  2501.07
# Neuroimage                       2100.5400  2326.43  2396.5700  2503.34
# Plos Genetics                    1465.7475  1712.73  1770.1950  1809.51
# Plos One                          851.9475   897.09  1040.7800  1785.36
# ...

# %%
top_five = wellcome_five.groupby('Journal title').median()
top_five
# Out:
#                                     cost
# Journal title
# Journal Of Biological Chemistry  1301.14
# Neuroimage                       2326.43
# Plos Genetics                    1712.73
# Plos One                          897.09
# Plos Pathogens                   1600.25
